# %% [markdown]
# <a href="https://colab.research.google.com/github/hainam2k5/hainam2k5.github.io/blob/main/arari_deep_q_bf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Setup**

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-joztg0v2
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-joztg0v2
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 76, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/factory.py", line 538, in collect_root_requirements
#     reqs = list(
#            ^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/factory.py", line 494, in _make_requirements_from_install_req
#     cand = self._make_base_candidate_from_link(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/factory.py", line 231, in _make_base_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#                                        ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 303, in __init__
#     super().__init__(
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 158, in __init__
#     self.dist = self._prepare()
#                 ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 235, in _prepare
#     dist = self._prepare_distribution()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 314, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/prepare.py", line 527, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/prepare.py", line 598, in _prepare_linked_requirement
#     local_file = unpack_url(
#                  ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/prepare.py", line 159, in unpack_url
#     unpack_vcs_link(link, location, verbosity=verbosity)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/prepare.py", line 81, in unpack_vcs_link
#     vcs_backend.unpack(location, url=hide_url(link.url), verbosity=verbosity)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/vcs/versioncontrol.py", line 589, in unpack
#     self.obtain(location, url=url, verbosity=verbosity)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/vcs/versioncontrol.py", line 502, in obtain
#     self.fetch_new(dest, url, rev_options, verbosity=verbosity)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/vcs/git.py", line 277, in fetch_new
#     self.run_command(
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/vcs/versioncontrol.py", line 631, in run_command
#     return call_subprocess(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/subprocess.py", line 151, in call_subprocess
#     line: str = proc.stdout.readline()
#                 ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.12/logging/__init__.py", line 1586, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1684, in _log
#     self.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1028, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/logging.py", line 169, in emit
#     renderable = self.render_message(record, message)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/rich/logging.py", line 185, in render_message
#     message_text = Text.from_markup(message) if use_markup else Text(message)
#                                                                 ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/rich/text.py", line 143, in __init__
#     def __init__(
#
# KeyboardInterrupt
# ^C

# %%
# !apt-get install swig cmake ffmpeg

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# # **Training**

# %%
# !python -m rl_zoo3.train --algo dqn  --env MsPacmanNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# |    fps              | 527      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 6008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 534      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 6641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 540      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 7215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 543      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 7793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 548      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 8391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 535      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 9024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 525      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 9687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 530      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 10304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 533      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 10920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 536      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 11599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 541      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 12506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 543      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 13088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 250      |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 545      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 13661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 248      |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 547      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 14252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 250      |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 549      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 14910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 252      |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 550      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 15471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 251      |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 539      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 16130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 249      |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 535      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 16772    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 536      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 17370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 538      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 17935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 539      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 18514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 541      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 19146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 543      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 19762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 546      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 20488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 547      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 20993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 549      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 21673    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 550      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 22259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 548      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 22872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 542      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 23489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 542      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 24147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 543      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 24752    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=334.00 +/- 139.23
# Episode length: 2188.20 +/- 679.08
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.19e+03 |
# |    mean_reward      | 334      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 477      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 25361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 478      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 25976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 475      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 26455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 475      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 27076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 478      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 27754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 480      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 28514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 483      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 29221    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 484      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 29761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 485      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 30233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 487      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 30884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 490      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 31845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 492      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 32764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 490      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 33400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.663    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 489      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 34014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 490      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 34505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 492      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 35135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.646    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 493      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 35792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 495      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 36466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 497      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 37078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 495      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 37660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 496      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 38086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 498      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 38682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 500      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 39346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 498      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 40037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 497      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 40573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 498      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 41231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 499      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 41876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 500      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 42443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.573    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 501      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 43109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.566    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 502      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 43875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 503      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 44579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 504      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 45260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 506      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 45996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 506      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 46594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 503      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 47269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 503      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 47784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.521    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 504      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 48404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 505      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 49189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 506      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 49830    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=368.00 +/- 266.19
# Episode length: 1903.40 +/- 629.28
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.9e+03  |
# |    mean_reward      | 368      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 471      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 50549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 472      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 51174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 474      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 51948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 475      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 52613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 476      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 53243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 477      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 53781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 479      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 54594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 480      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 55254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.446    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 481      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 55929    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 482      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 56637    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 481      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 57175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 480      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 57828    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 481      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 58387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 482      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 59057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 483      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 59661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.403    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 484      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 60321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 485      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 60986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 486      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 61521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 487      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 62234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 488      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 62911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 489      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 63446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 488      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 64104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 487      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 64709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 488      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 65354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 489      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 65944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 490      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 66481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 491      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 67042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 492      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 67989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.32     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 493      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 68685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 494      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 69343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 495      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 70085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 496      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 70692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 495      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 71335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 494      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 71992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 495      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 72588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.275    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 496      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 73221    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 496      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 73755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.264    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 497      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 74341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 498      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 74991    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=288.00 +/- 85.18
# Episode length: 1893.80 +/- 307.12
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.89e+03 |
# |    mean_reward      | 288      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.251    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 471      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 75698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.245    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 472      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 76244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 473      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 76825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.234    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 474      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 77423    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 475      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 78121    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.22     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 475      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 78768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.215    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 476      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 79276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.207    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 477      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 80134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.201    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 477      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 80676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 477      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 81247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.191    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 477      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 81750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.184    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 477      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 82392    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.178    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 478      |
# |    time_elapsed     | 173      |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.275    |
# |    n_updates        | 37300    |
# ----------------------------------
# Eval num_timesteps=250000, episode_reward=408.00 +/- 36.55
# Episode length: 1633.00 +/- 205.90
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.63e+03 |
# |    mean_reward      | 408      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 250000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0894   |
# |    n_updates        | 37499    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 750      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 48       |
# |    time_elapsed     | 5189     |
# |    total_timesteps  | 250131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0772   |
# |    n_updates        | 37532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 764      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 48       |
# |    time_elapsed     | 5212     |
# |    total_timesteps  | 250811   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0748   |
# |    n_updates        | 37702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 782      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 47       |
# |    time_elapsed     | 5246     |
# |    total_timesteps  | 251811   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 37952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 777      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 47       |
# |    time_elapsed     | 5269     |
# |    total_timesteps  | 252498   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 38124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 774      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 47       |
# |    time_elapsed     | 5297     |
# |    total_timesteps  | 253323   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 38330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 772      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 47       |
# |    time_elapsed     | 5332     |
# |    total_timesteps  | 254342   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0916   |
# |    n_updates        | 38585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 778      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 47       |
# |    time_elapsed     | 5361     |
# |    total_timesteps  | 255200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.391    |
# |    n_updates        | 38799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 777      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 47       |
# |    time_elapsed     | 5389     |
# |    total_timesteps  | 256017   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0493   |
# |    n_updates        | 39004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 776      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 47       |
# |    time_elapsed     | 5415     |
# |    total_timesteps  | 256784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0621   |
# |    n_updates        | 39195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 776      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 47       |
# |    time_elapsed     | 5446     |
# |    total_timesteps  | 257707   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0695   |
# |    n_updates        | 39426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 786      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 47       |
# |    time_elapsed     | 5478     |
# |    total_timesteps  | 258645   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 39661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 784      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 47       |
# |    time_elapsed     | 5516     |
# |    total_timesteps  | 259769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 39942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 800      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 47       |
# |    time_elapsed     | 5533     |
# |    total_timesteps  | 260258   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0404   |
# |    n_updates        | 40064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 771      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 46       |
# |    time_elapsed     | 5551     |
# |    total_timesteps  | 260776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 40193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 776      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 46       |
# |    time_elapsed     | 5591     |
# |    total_timesteps  | 261927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.114    |
# |    n_updates        | 40481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 780      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 46       |
# |    time_elapsed     | 5615     |
# |    total_timesteps  | 262626   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.442    |
# |    n_updates        | 40656    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 782      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 46       |
# |    time_elapsed     | 5649     |
# |    total_timesteps  | 263641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 40910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 784      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 46       |
# |    time_elapsed     | 5675     |
# |    total_timesteps  | 264416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 41103    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 788      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 46       |
# |    time_elapsed     | 5711     |
# |    total_timesteps  | 265466   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.162    |
# |    n_updates        | 41366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 784      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 46       |
# |    time_elapsed     | 5732     |
# |    total_timesteps  | 266057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.235    |
# |    n_updates        | 41514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 782      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 46       |
# |    time_elapsed     | 5750     |
# |    total_timesteps  | 266603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.151    |
# |    n_updates        | 41650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 779      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 46       |
# |    time_elapsed     | 5783     |
# |    total_timesteps  | 267524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.342    |
# |    n_updates        | 41880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 773      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 46       |
# |    time_elapsed     | 5800     |
# |    total_timesteps  | 268039   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.186    |
# |    n_updates        | 42009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 773      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 46       |
# |    time_elapsed     | 5825     |
# |    total_timesteps  | 268769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 42192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 773      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 46       |
# |    time_elapsed     | 5859     |
# |    total_timesteps  | 269717   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0457   |
# |    n_updates        | 42429    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 802      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 45       |
# |    time_elapsed     | 5891     |
# |    total_timesteps  | 270680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.047    |
# |    n_updates        | 42669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 799      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 45       |
# |    time_elapsed     | 5923     |
# |    total_timesteps  | 271531   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.35     |
# |    n_updates        | 42882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 792      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1484     |
# |    fps              | 45       |
# |    time_elapsed     | 5946     |
# |    total_timesteps  | 272210   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.051    |
# |    n_updates        | 43052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.48e+03 |
# |    ep_rew_mean      | 790      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 45       |
# |    time_elapsed     | 5975     |
# |    total_timesteps  | 273020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.303    |
# |    n_updates        | 43254    |
# ----------------------------------
# Saving to logs//dqn/MsPacmanNoFrameskip-v4_1

# %% [markdown]
# # **Record Vedio**

# %%
# !python -m rl_zoo3.record_video  --algo dqn  --env MsPacmanNoFrameskip-v4  --folder logs/  --n-timesteps 1000
# Out:
# 2025-11-12 18:39:41.102383: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762972781.140495   25600 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762972781.152923   25600 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762972781.197017   25600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762972781.197071   25600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762972781.197167   25600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762972781.197180   25600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-12 18:39:41.210404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/MsPacmanNoFrameskip-v4_1/MsPacmanNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Loading logs/dqn/MsPacmanNoFrameskip-v4_1/MsPacmanNoFrameskip-v4.zip
# Wrapping the env in a VecTransposeImage.
# Saving video to /content/logs/dqn/MsPacmanNoFrameskip-v4_1/videos/final-model-dqn-MsPacmanNoFrameskip-v4-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/logs/dqn/MsPacmanNoFrameskip-v4_1/videos/final-model-dqn-MsPacmanNoFrameskip-v4-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/logs/dqn/MsPacmanNoFrameskip-v4_1/videos/final-model-dqn-MsPacmanNoFrameskip-v4-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/logs/dqn/MsPacmanNoFrameskip-v4_1/videos/final-model-dqn-MsPacmanNoFrameskip-v4-step-0-to-step-1000.mp4

# %%
# !ls logs
# !rm -rf logs/*
# Out:
# dqn

# %% [markdown]
# # **Evaluate**

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env MsPacmanNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# # **Push to Hub**

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env MsPacmanNoFrameskip-v4  --repo-name dqn-MsPacmanNoFrameskip-v4  -orga YoungMeng  -f logs/
